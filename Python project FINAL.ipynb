# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
##Import the required libraries, Read the csv file, check the imported file.
stock=pd.read_csv("HDFCBANK.csv")
stock
# Out:
#             Date    Symbol Series  Prev Close     Open     High      Low  \
# 0     03-01-2000  HDFCBANK     EQ      157.40   166.00   170.00   166.00
# 1     04-01-2000  HDFCBANK     EQ      170.00   182.00   183.45   171.00
# 2     05-01-2000  HDFCBANK     EQ      173.80   170.00   173.90   165.00
# 3     06-01-2000  HDFCBANK     EQ      166.95   168.00   170.00   165.30
# 4     07-01-2000  HDFCBANK     EQ      168.30   162.15   171.00   162.15
# ...          ...       ...    ...         ...      ...      ...      ...
# 5301  26-04-2021  HDFCBANK     EQ     1414.15  1413.00  1429.00  1402.75
# 5302  27-04-2021  HDFCBANK     EQ     1404.80  1407.25  1442.00  1404.80
# 5303  28-04-2021  HDFCBANK     EQ     1438.70  1436.25  1479.00  1431.00
# 5304  29-04-2021  HDFCBANK     EQ     1476.80  1486.20  1503.65  1461.00
# 5305  30-04-2021  HDFCBANK     EQ     1472.50  1445.00  1453.80  1407.50
#
#          Last    Close     VWAP    Volume      Turnover    Trades  \
# ...

# %%
##List the top 5 trades?
stock.head()
# Out:
#          Date    Symbol Series  Prev Close    Open    High     Low    Last  \
# 0  03-01-2000  HDFCBANK     EQ      157.40  166.00  170.00  166.00  170.00
# 1  04-01-2000  HDFCBANK     EQ      170.00  182.00  183.45  171.00  174.00
# 2  05-01-2000  HDFCBANK     EQ      173.80  170.00  173.90  165.00  168.00
# 3  06-01-2000  HDFCBANK     EQ      166.95  168.00  170.00  165.30  168.95
# 4  07-01-2000  HDFCBANK     EQ      168.30  162.15  171.00  162.15  170.75
#
#     Close    VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# 0  170.00  169.52   33259  5.640000e+11     NaN                 NaN
# 1  173.80  174.99  168710  2.950000e+12     NaN                 NaN
# 2  166.95  169.20  159820  2.700000e+12     NaN                 NaN
# 3  168.30  168.44   85026  1.430000e+12     NaN                 NaN
# 4  168.35  166.79   85144  1.420000e+12     NaN                 NaN
#
#    %Deliverble
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
##List the bottom 5 trades?
stock.tail()
# Out:
#             Date    Symbol Series  Prev Close     Open     High      Low  \
# 5301  26-04-2021  HDFCBANK     EQ     1414.15  1413.00  1429.00  1402.75
# 5302  27-04-2021  HDFCBANK     EQ     1404.80  1407.25  1442.00  1404.80
# 5303  28-04-2021  HDFCBANK     EQ     1438.70  1436.25  1479.00  1431.00
# 5304  29-04-2021  HDFCBANK     EQ     1476.80  1486.20  1503.65  1461.00
# 5305  30-04-2021  HDFCBANK     EQ     1472.50  1445.00  1453.80  1407.50
#
#          Last   Close     VWAP    Volume      Turnover    Trades  \
# 5301  1407.55  1404.8  1413.19  15085476  2.130000e+15  291268.0
# 5302  1435.05  1438.7  1430.40  10296453  1.470000e+15  233200.0
# 5303  1475.00  1476.8  1463.19  12051970  1.760000e+15  197146.0
# 5304  1471.65  1472.5  1481.15  12039276  1.780000e+15  252296.0
# 5305  1412.90  1412.3  1421.13  17616451  2.500000e+15  447876.0
#
#       Deliverable Volume  %Deliverble
# 5301           9791881.0       0.6491
# 5302           5650216.0       0.5488
# ...

# %%
stock.dtypes
# Out:
# Date                   object
# Symbol                 object
# Series                 object
# Prev Close            float64
# Open                  float64
# High                  float64
# Low                   float64
# Last                  float64
# Close                 float64
# VWAP                  float64
# Volume                  int64
# Turnover              float64
# Trades                float64
# Deliverable Volume    float64
# %Deliverble           float64
# dtype: object

# %%
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                5306 non-null   object
#  1   Symbol              5306 non-null   object
#  2   Series              5306 non-null   object
#  3   Prev Close          5306 non-null   float64
#  4   Open                5306 non-null   float64
#  5   High                5306 non-null   float64
#  6   Low                 5306 non-null   float64
#  7   Last                5306 non-null   float64
#  8   Close               5306 non-null   float64
#  9   VWAP                5306 non-null   float64
#  10  Volume              5306 non-null   int64
#  11  Turnover            5306 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  4797 non-null   float64
#  14  %Deliverble         4797 non-null   float64
# ...

# %%
stock.describe(include='all')
# Out:
#               Date    Symbol Series   Prev Close         Open         High  \
# count         5306      5306   5306  5306.000000  5306.000000  5306.000000
# unique        5306         1      1          NaN          NaN          NaN
# top     03-01-2000  HDFCBANK     EQ          NaN          NaN          NaN
# freq             1      5306   5306          NaN          NaN          NaN
# mean           NaN       NaN    NaN  1007.093884  1007.472767  1019.986939
# std            NaN       NaN    NaN   635.757762   635.461516   641.444674
# min            NaN       NaN    NaN   157.400000   162.150000   167.900000
# 25%            NaN       NaN    NaN   479.912500   482.112500   486.912500
# 50%            NaN       NaN    NaN   934.750000   939.350000   953.950000
# 75%            NaN       NaN    NaN  1421.000000  1423.525000  1440.000000
# max            NaN       NaN    NaN  2565.800000  2566.000000  2583.300000
#
# ...

# %%
stock.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  5306.000000  5306.000000  5306.000000  5306.000000  5306.000000
# mean   1007.093884  1007.472767  1019.986939   993.822211  1007.364003
# std     635.757762   635.461516   641.444674   629.502818   635.722752
# min     157.400000   162.150000   167.900000   157.000000   163.000000
# 25%     479.912500   482.112500   486.912500   473.100000   480.700000
# 50%     934.750000   939.350000   953.950000   922.175000   935.600000
# 75%    1421.000000  1423.525000  1440.000000  1399.000000  1422.812500
# max    2565.800000  2566.000000  2583.300000  2553.700000  2563.000000
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count  5306.000000  5306.000000  5.306000e+03  5.306000e+03    2456.000000
# mean   1007.330390  1006.929263  2.102580e+06  2.448905e+14   82923.625407
# std     635.675021   635.481917  3.970048e+06  4.780096e+14   93575.061741
# ...

# %%
stock.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
S1=stock[['Date','Prev Close','Open','High','Low','Last','Close','Volume']]
S1
# Out:
#             Date  Prev Close     Open     High      Low     Last    Close  \
# 0     03-01-2000      157.40   166.00   170.00   166.00   170.00   170.00
# 1     04-01-2000      170.00   182.00   183.45   171.00   174.00   173.80
# 2     05-01-2000      173.80   170.00   173.90   165.00   168.00   166.95
# 3     06-01-2000      166.95   168.00   170.00   165.30   168.95   168.30
# 4     07-01-2000      168.30   162.15   171.00   162.15   170.75   168.35
# ...          ...         ...      ...      ...      ...      ...      ...
# 5301  26-04-2021     1414.15  1413.00  1429.00  1402.75  1407.55  1404.80
# 5302  27-04-2021     1404.80  1407.25  1442.00  1404.80  1435.05  1438.70
# 5303  28-04-2021     1438.70  1436.25  1479.00  1431.00  1475.00  1476.80
# 5304  29-04-2021     1476.80  1486.20  1503.65  1461.00  1471.65  1472.50
# 5305  30-04-2021     1472.50  1445.00  1453.80  1407.50  1412.90  1412.30
#
#         Volume
# 0        33259
# 1       168710
# 2       159820
# ...

# %%
stock.set_index(pd.DatetimeIndex(stock['Date']),inplace= True)

# %%
stock.dtypes
# Out:
# Date                  datetime64[ns]
# Symbol                        object
# Series                        object
# Prev Close                   float64
# Open                         float64
# High                         float64
# Low                          float64
# Last                         float64
# Close                        float64
# VWAP                         float64
# Volume                         int64
# Turnover                     float64
# Trades                       float64
# Deliverable Volume           float64
# %Deliverble                  float64
# dtype: object

# %%
S1.dtypes
# Out:
# Date          datetime64[ns]
# Prev Close           float64
# Open                 float64
# High                 float64
# Low                  float64
# Last                 float64
# Close                float64
# Volume                 int64
# dtype: object

# %%
S1=S1.set_index('Date')
ax=S1.plot(color="red")
ax.set_ylabels('High')
ax.set_xlabels('Date')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14272/1186659231.py in <module>
#       1 S1=S1.set_index('Date')
#       2 ax=S1.plot(color="red")
# ----> 3 ax.set_ylabels('High')
#       4 ax.set_xlabels('Date')
#       5 plt.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'set_ylabels'

# %%
S1['Close'].plot()
plt.show()

# %%
S1['Volume'].plot()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
S1.iloc[5000:5305,4:6]
# Out:
#           Low     Last
# 5000  1227.30  1246.00
# 5001  1237.20  1239.95
# 5002  1231.60  1240.00
# 5003  1226.05  1240.95
# 5004  1238.05  1239.90
# ...       ...      ...
# 5300  1400.20  1414.95
# 5301  1402.75  1407.55
# 5302  1404.80  1435.05
# 5303  1431.00  1475.00
# 5304  1461.00  1471.65
#
# [305 rows x 2 columns]

# %%
Closing=S1.iloc[5000:5305,4:6]
Closing
# Out:
#           Low     Last
# 5000  1227.30  1246.00
# 5001  1237.20  1239.95
# 5002  1231.60  1240.00
# 5003  1226.05  1240.95
# 5004  1238.05  1239.90
# ...       ...      ...
# 5300  1400.20  1414.95
# 5301  1402.75  1407.55
# 5302  1404.80  1435.05
# 5303  1431.00  1475.00
# 5304  1461.00  1471.65
#
# [305 rows x 2 columns]

# %%
Closing['Close'].plot()
plt.show()

# %%
ax=Closing.plot(linewidth=2)

ax.axvspan('2020-07','2021-01',color='green',alpha=.4)
ax.axhspan('1000','4000',color='red',alpha=.3) 
plt.show()

# %%
C=stock[['Date','High','Low','Volume']]
C
# Out:
#            Date     High      Low    Volume
# 0    2000-03-01   170.00   166.00     33259
# 1    2000-04-01   183.45   171.00    168710
# 2    2000-05-01   173.90   165.00    159820
# 3    2000-06-01   170.00   165.30     85026
# 4    2000-07-01   171.00   162.15     85144
# ...         ...      ...      ...       ...
# 5301 2021-04-26  1429.00  1402.75  15085476
# 5302 2021-04-27  1442.00  1404.80  10296453
# 5303 2021-04-28  1479.00  1431.00  12051970
# 5304 2021-04-29  1503.65  1461.00  12039276
# 5305 2021-04-30  1453.80  1407.50  17616451
#
# [5306 rows x 4 columns]

# %%
C1=C.iloc[5000:5305,0:3]
C1
# Out:
#            Date     High      Low
# 5000 2020-05-02  1248.00  1227.30
# 5001 2020-06-02  1248.70  1237.20
# 5002 2020-07-02  1247.00  1231.60
# 5003 2020-10-02  1242.95  1226.05
# 5004 2020-11-02  1255.00  1238.05
# ...         ...      ...      ...
# 5300 2021-04-23  1434.60  1400.20
# 5301 2021-04-26  1429.00  1402.75
# 5302 2021-04-27  1442.00  1404.80
# 5303 2021-04-28  1479.00  1431.00
# 5304 2021-04-29  1503.65  1461.00
#
# [305 rows x 3 columns]

# %%
ax=C1.plot(linewidth=2)

ax.axvspan('2020-10','2021'-1,color='red',alpha=.4)

ax.axhspan(1000,1200,color='green',alpha=.3)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7796/3910583368.py in <module>
#       1 ax=C1.plot(linewidth=2)
#       2
# ----> 3 ax.axvspan('2020-10','2021'-1,color='red',alpha=.4)
#       4
#       5 ax.axhspan(1000,1200,color='green',alpha=.3)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
C1.boxplot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import sklearn.metrics as metrics

# %%
sns.boxplot(S1['High'])
# Out:
# C:\python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='High'>

# %%
sns.boxplot(S1['Low'])
# Out:
# C:\python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Low'>

# %%
#Splitting the dataset into Training set and Test set
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16664/1469055189.py in <module>
#       1 #Splitting the dataset into Training set and Test set
#       2 from sklearn.model_selection import train_test_split
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)
#       4 print(X_train.shape)
#       5 print(X_test.shape)
#
# NameError: name 'X' is not defined

# %%
#Defining the independent (X) 
X=stock[['High','Low','Open','Last','Close']]
X
# Out:
#          High      Low     Open     Last    Close
# 0      170.00   166.00   166.00   170.00   170.00
# 1      183.45   171.00   182.00   174.00   173.80
# 2      173.90   165.00   170.00   168.00   166.95
# 3      170.00   165.30   168.00   168.95   168.30
# 4      171.00   162.15   162.15   170.75   168.35
# ...       ...      ...      ...      ...      ...
# 5301  1429.00  1402.75  1413.00  1407.55  1404.80
# 5302  1442.00  1404.80  1407.25  1435.05  1438.70
# 5303  1479.00  1431.00  1436.25  1475.00  1476.80
# 5304  1503.65  1461.00  1486.20  1471.65  1472.50
# 5305  1453.80  1407.50  1445.00  1412.90  1412.30
#
# [5306 rows x 5 columns]

# %%
#Defining dependent (y) variables
y=stock['Date']
y
# Out:
# 0      2000-03-01
# 1      2000-04-01
# 2      2000-05-01
# 3      2000-06-01
# 4      2000-07-01
#           ...
# 5301   2021-04-26
# 5302   2021-04-27
# 5303   2021-04-28
# 5304   2021-04-29
# 5305   2021-04-30
# Name: Date, Length: 5306, dtype: datetime64[ns]

# %%
#Splitting the dataset into Training set and Test set
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4244, 5)
# (1062, 5)
# (4244,)
# (1062,)

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#Predicting the Test set results
y_pred=model.predict(X_test)
y_pred
# Out:
# array([1.33458822e+18, 1.22100515e+18, 1.29658828e+18, ...,
#        1.18597344e+18, 1.17011796e+18, 1.13345693e+18])

# %%
# Actual and Predicited value
df1 = pd.DataFrame(data={'Predicted value':y_pred,'Actual Value':y_test})
df1
# Out:
#       Predicted value Actual Value
# 4922     1.334588e+18   2019-10-16
# 3492     1.221005e+18   2013-12-26
# 1770     1.296588e+18   2007-01-18
# 2687     1.600936e+18   2010-06-10
# 1693     1.278061e+18   2006-09-27
# ...               ...          ...
# 959      1.154659e+18   2003-10-30
# 3640     1.261921e+18   2014-07-31
# 2940     1.185973e+18   2011-11-10
# 1615     1.170118e+18   2006-09-06
# 647      1.133457e+18   2002-01-08
#
# [1062 rows x 2 columns]

# %%
#Plot the regression plot
sns.regplot(x=y_test,y=y_pred)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14272/3332546084.py in <module>
#       1 #Plot the regression plot
# ----> 2 sns.regplot(x=y_test,y=y_pred)
#       3 plt.xlabel('Y Test')
#       4 plt.ylabel('Predicted Y')
#
# C:\python\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\python\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     861     scatter_kws["marker"] = marker
# ...

# %%
import statsmodels.api as sm
X_train_Sm= sm.add_constant(X_train)
ls=sm.OLS(y_train,X_train_Sm).fit()
ls.summary()
# Out:
# C:\python\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Volume   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     32.50
# Date:                Mon, 18 Apr 2022   Prob (F-statistic):           1.26e-32
# Time:                        14:57:59   Log-Likelihood:                -70490.
# No. Observations:                4244   AIC:                         1.410e+05
# Df Residuals:                    4238   BIC:                         1.410e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
